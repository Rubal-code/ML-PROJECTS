# %%
import pandas as pd
import numpy as np
import re 
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# printing the stopwords of the english 
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %%
df=pd.read_csv('FakeNewsNet.csv')

# %%
df.shape
# Out:
# (23196, 5)

# %%
df.sample(10)
# Out:
#                                                    title  \
# 2257   Angelina Jolie, 'Focused on Healing Her Family...
# 8056   Coachella 2018 lineup: Beyoncé, Eminem and The...
# 2757       Did Demi Lovato Throw Shade at Kathy Griffin?
# 11342  Ben Affleck treats cast and crew of 500 to Haw...
# 652    Big shoes to fill! AnnaSophia Robb swaps her h...
# 16617                                     Esteban Loaiza
# 5536                                Jill Zarin Net Worth
# 17745      You Are My Friend News, Casting, Release Date
# 10881  BUSTED: Russian Mansions Obama Seized Were Mea...
# 20069  Justin Bieber and Selena Gomez Go to the Airpo...
#
#                                                 news_url  \
# 2257   people.com/movies/angelina-jolie-splits-lawyer...
# 8056   https://www.usatoday.com/story/life/music/2018...
# 2757   https://www.usmagazine.com/celebrity-news/news...
# 11342  www.dailymail.co.uk/tvshowbiz/article-5645343/...
# 652    https://www.dailymail.co.uk/tvshowbiz/article-...
# 16617       https://en.wikipedia.org/wiki/Esteban_Loaiza
# 5536   https://www.celebritynetworth.com/richest-cele...
# 17745  https://www.townandcountrymag.com/leisure/arts...
# 10881  dailyfeed.news/russian-mansions-obama-seized-w...
# 20069  https://frostsnow.com/justin-bieber-and-selena...
#
#                    source_domain  tweet_num  real
# 2257                  people.com         57     0
# 8056            www.usatoday.com        678     1
# 2757          www.usmagazine.com        114     1
# 11342        www.dailymail.co.uk         11     0
# 652          www.dailymail.co.uk         65     1
# 16617           en.wikipedia.org         17     1
# 5536   www.celebritynetworth.com          1     1
# 17745  www.townandcountrymag.com         76     1
# 10881             dailyfeed.news         42     0
# 20069              frostsnow.com        113     1

# %%
df.describe()
# Out:
#           tweet_num          real
# count  23196.000000  23196.000000
# mean      88.956803      0.751897
# std      488.694592      0.431921
# min        0.000000      0.000000
# 25%       11.000000      1.000000
# 50%       37.000000      1.000000
# 75%       65.000000      1.000000
# max    29060.000000      1.000000

# %%
df.isnull().sum()
# Out:
# title              0
# news_url         330
# source_domain    330
# tweet_num          0
# real               0
# dtype: int64

# %%
# fill the null values with the empty string by making the new dataframe
df_1=df.fillna(' ')

# %%
df_1.isnull().sum()
# Out:
# title            0
# news_url         0
# source_domain    0
# tweet_num        0
# real             0
# dtype: int64

# %%
# merging the two cols title and source_domain as content
df_1['content']=df_1['source_domain']+" "+df_1['title']

# %%
df_1.sample(5)
# Out:
#                                                    title  \
# 8826   Amal Clooney Wears a Lingerie-Inspired Top Lik...
# 17129  Lena Headey Recalls How Harvey Weinstein Made ...
# 3288   Nick Viall Regrets Telling Ashley Iaconetti Sh...
# 14634        Zac Efron searches for love on Room Raiders
# 11045  Pregnant Khloe Kardashian Shows Off Bare Baby ...
#
#                                                 news_url  \
# 8826   https://www.kartiavelino.com/2018/04/amal-cloo...
# 17129  https://www.huffingtonpost.com/entry/game-of-t...
# 3288   https://www.usmagazine.com/celebrity-news/news...
# 14634  https://ew.com/tv/2017/04/24/zac-efron-room-ra...
# 11045  https://www.usmagazine.com/celebrity-moms/news...
#
#                 source_domain  tweet_num  real  \
# 8826     www.kartiavelino.com         31     1
# 17129  www.huffingtonpost.com         23     1
# 3288       www.usmagazine.com         62     1
# 14634                  ew.com         59     1
# 11045      www.usmagazine.com         13     1
#
#                                                  content
# 8826   www.kartiavelino.com Amal Clooney Wears a Ling...
# 17129  www.huffingtonpost.com Lena Headey Recalls How...
# 3288   www.usmagazine.com Nick Viall Regrets Telling ...
# 14634  ew.com Zac Efron searches for love on Room Rai...
# 11045  www.usmagazine.com Pregnant Khloe Kardashian S...

# %%
df_2=df_1.drop(columns=['source_domain','title'])

# %%
df_2.head()
# Out:
#                                             news_url  tweet_num  real  \
# 0  http://toofab.com/2017/05/08/real-housewives-a...         42     1
# 1  https://www.today.com/style/see-people-s-choic...          0     1
# 2  https://www.etonline.com/news/220806_sophia_bu...         63     1
# 3  https://www.dailymail.co.uk/news/article-33655...         20     1
# 4  https://www.zerchoo.com/entertainment/gossip-g...         38     1
#
#                                              content
# 0  toofab.com Kandi Burruss Explodes Over Rape Ac...
# 1  www.today.com People's Choice Awards 2018: The...
# 2  www.etonline.com Sophia Bush Sends Sweet Birth...
# 3  www.dailymail.co.uk Colombian singer Maluma sp...
# 4  www.zerchoo.com Gossip Girl 10 Years Later: Ho...

# %%
X=df_2.drop(columns='real')
y=df_2.iloc[:,[2]]

# %% [markdown]
# stemming : stemming is processs of reducing word to its root word
# example : actor , actress , acting --> act

# %%
port_stem=PorterStemmer()

# %%
def stemming(content):
    stemmed_content=re.sub('[^a-zA-Z]',' ',content) # replace words other then the alphabet with space 
    stemmed_content=stemmed_content.lower()
    stemmed_content=stemmed_content.split()
    stemmed_content=[port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content=' '.join(stemmed_content)
    return stemmed_content

# %%
df_2['content']=df_2['content'].apply(stemming)

# %%
print(df_2['content'])
# Out:
# 0        toofab com kandi burruss explod rape accus rea...
# 1        www today com peopl choic award best red carpe...
# 2        www etonlin com sophia bush send sweet birthda...
# 3        www dailymail co uk colombian singer maluma sp...
# 4        www zerchoo com gossip girl year later upper e...
#                                ...
# 23191    www express co uk pippa middleton wed case mis...
# 23192    hollywoodlif com zayn malik gigi hadid shock s...
# 23193    www justjar com jessica chastain recal moment ...
# 23194    www intouchweekli com tristan thompson feel du...
# 23195    www billboard com kelli clarkson perform medle...
# Name: content, Length: 23196, dtype: object

# %%
X1=df_2['content'].values
y1=df_2['real'].values

# %%
X1,y1
# Out:
# (array(['toofab com kandi burruss explod rape accus real housew atlanta reunion video',
#         'www today com peopl choic award best red carpet look',
#         'www etonlin com sophia bush send sweet birthday messag one tree hill co star hilari burton breyton eva',
#         ...,
#         'www justjar com jessica chastain recal moment mother boyfriend slap kick genit',
#         'www intouchweekli com tristan thompson feel dump khlo kardashian refus let move la home exclus',
#         'www billboard com kelli clarkson perform medley kendrick lamar humbl hit billboard music award'],
#        dtype=object),
#  array([1, 1, 1, ..., 1, 0, 1]))

# %%
# converting the textual data into numerical so the machine can understand
vectorizer=TfidfVectorizer()
X1=vectorizer.fit_transform(X1)
print(X1)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 246417 stored elements and shape (23196, 14435)>
#   Coords	Values
#   (0, 12980)	0.2946734912504806
#   (0, 2460)	0.0508218665886508
#   (0, 6647)	0.38749399933436923
#   (0, 1707)	0.38749399933436923
#   (0, 4193)	0.35506164978733906
#   (0, 10223)	0.302158398468634
#   (0, 59)	0.2597097788538541
#   (0, 10276)	0.23128301802698967
#   (0, 5891)	0.26124620267491605
#   (0, 651)	0.30737565657585053
#   (0, 10569)	0.2543303205934995
#   (0, 13681)	0.21108934405813046
#   (1, 2460)	0.08159478582438673
#   (1, 14274)	0.10189043319535994
#   (1, 12946)	0.3681704416327513
#   (1, 9476)	0.2369741457556781
#   (1, 2219)	0.42251489448694257
#   (1, 729)	0.3083771474680274
#   (1, 1101)	0.3384429489202671
#   (1, 10347)	0.37702288594702094
#   (1, 1916)	0.3875096512688879
#   (1, 7432)	0.3328445485941059
#   (2, 2460)	0.04356960323673351
#   (2, 14274)	0.05440697837598742
#   (2, 4091)	0.16595541576226283
#   :	:
#   (23194, 3695)	0.31679451408881903
#   (23194, 4159)	0.24664304708295876
#   (23194, 6661)	0.17479540394859372
#   (23194, 6994)	0.26381957644897924
#   (23194, 5800)	0.2632849856372537
#   (23194, 6797)	0.28785051901050934
#   (23194, 13154)	0.2717482205740398
#   (23194, 12818)	0.26985982917564694
#   (23194, 4387)	0.2692478125672807
#   (23194, 7230)	0.30870481533818256
#   (23194, 8384)	0.2822154791515417
#   (23194, 10393)	0.31860580642240854
#   (23195, 2460)	0.04830752475490311
#   (23195, 14274)	0.060323396576666556
#   (23195, 729)	0.18257216480989652
#   (23195, 9497)	0.23609444741706065
#   (23195, 8457)	0.21409156547616323
#   (23195, 1167)	0.44359883337472966
#   (23195, 6732)	0.23172295312137026
#   (23195, 5754)	0.2561748235324755
#   (23195, 7037)	0.2988459804176233
#   (23195, 2318)	0.27348859087437083
#   (23195, 5941)	0.3819332333944831
#   (23195, 6749)	0.33243273972601206
#   (23195, 7960)	0.3500409208295561

# %% [markdown]
# ***train -test - split***

# %%
X_train,X_test,y_train,y_test=train_test_split(X1,y1,test_size=0.2,stratify=y,random_state=42)

# %%
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.8620689655172413

# %% [markdown]
# **predictive system**

# %%
X_new=X_test[0]
prediction=model.predict(X_new)
print(prediction)
if(prediction[0]==0):
    print('real')
else:
    print('fake')
# Out:
# [1]
# fake

# %%
print(y_test[0])
# Out:
# 1
